# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # New Section

# %%
df=pd.read_csv("/content/haberman.csv")

# %%
df.head()
# Out:
#    age  year  nodes  status
# 0   30    64      1       1
# 1   30    62      3       1
# 2   30    65      0       1
# 3   31    59      2       1
# 4   31    65      4       1

# %%
df.shape
# Out:
# (306, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 4 columns):
# age       306 non-null int64
# year      306 non-null int64
# nodes     306 non-null int64
# status    306 non-null int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %%
#univariant analysis
#1.age	
#2.year	
#3.nodes
#4.status

# %%
#box plot #violinplot histogram
sns.boxplot(data=df,x="status",y="age")
sns.set_style("dark")

# %%
sns.violinplot(data=df,x="status",y="age",set_style="whitegrid")

# %%
sns.FacetGrid(df,hue="status",size=5)\
.map(sns.distplot,"age")\
.add_legend
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
status_1=df[df["status"]==1]

# %%
status_2=df[df["status"]==2]

# %%
status_2
# Out:
#      age  year  nodes  status
# 7     34    59      0       2
# 8     34    66      9       2
# 24    38    69     21       2
# 34    39    66      0       2
# 43    41    60     23       2
# ..   ...   ...    ...     ...
# 286   70    58      4       2
# 293   72    63      0       2
# 299   74    65      3       2
# 304   78    65      1       2
# 305   83    58      2       2
#
# [81 rows x 4 columns]

# %%
count,edges=np.histogram(status_1["age"],bins=10,density=True)
pdf=count/sum(count)
cdf=np.cumsum(pdf)
plt.plot(edges[1:],pdf,label="PDF for status1")
plt.plot(edges[1:],cdf,label="CDF for status1")
plt.show
#status_2
count1,bin_edges=np.histogram(status_2["age"],bins=5,density=True)
pdf=count1/(sum(count1))
pdf
cdf=np.cumsum(pdf)

plt.plot(bin_edges[1:],pdf,label="PDF for status2",color="r")
plt.plot(bin_edges[1:],cdf,label="CDF for status2",color="g")
plt.xlabel("CDF and PDF for age ")
plt.ylabel("Percentage")
plt.legend()
plt.show()

# %%
#univariant analysis with feature year

df.sort_values(by=["year"])
# Out:
#      age  year  nodes  status
# 305   83    58      2       2
# 258   65    58      0       2
# 253   64    58      0       1
# 37    39    58      0       1
# 40    40    58      2       1
# ..   ...   ...    ...     ...
# 176   54    69      7       1
# 53    42    69      1       2
# 142   52    69      3       2
# 50    41    69      8       1
# 90    46    69      3       2
#
# [306 rows x 4 columns]

# %%
df["year"].value_counts()
# Out:
# 58    36
# 64    31
# 63    30
# 66    28
# 65    28
# 60    28
# 59    27
# 61    26
# 67    25
# 62    23
# 68    13
# 69    11
# Name: year, dtype: int64

# %%
sns.FacetGrid(df,hue="status",size=5)\
.map(sns.distplot,"year")\
.add_legend
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#nodes
#boxplot
sns.boxplot(x=df["status"],y=df["nodes"])

# %%
sns.violinplot(x=df["status"],y=df["nodes"],set_style="whitegrid")

# %%
sns.FacetGrid(df,hue="status",size=5)\
.map(sns.distplot,"nodes")\
.add_legend
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#PDF and CDF of feature nodes with respect to status

counts,edges=np.histogram(status_1["nodes"],bins=10)
pdf=counts/sum(counts)
cdf=np.cumsum(pdf)
plt.plot(edges[1:],pdf,label="PDF for status1")
plt.plot(edges[1:],cdf,label="CDF for status1")

counts,edges=np.histogram(status_2["nodes"],bins=10)
pdf=counts/sum(counts)
cdf=np.cumsum(pdf)
plt.plot(edges[1:],pdf,label="PDF for status2")
plt.plot(edges[1:],cdf,label="CDF for status2")
plt.legend()
plt.show()

# %%
sns.pairplot(df,hue="status",kind="scatter",vars=["age","nodes","year"])

# %%
sns.jointplot("age","nodes",data=df,color="r")
